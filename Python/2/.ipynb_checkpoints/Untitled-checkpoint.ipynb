# %% [markdown]
# # if-else语句

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 单条件

# %%
num = int(input('你觉得现在小明想的数字是什么：'))
num1 = 5 
if num == num1:  #判断    
    print('恭喜你猜对了，看来你们真是心有灵犀')   
else:    
    print('很遗憾，你居然不知道你朋友心中所想')
# Out:
# 你觉得现在小明想的数字是什么：5
# 恭喜你猜对了，看来你们真是心有灵犀

# %% [markdown]
# ## 多个条件

# %%
import random 
inp = int(input('请出拳：')) 
computer = random.randint(0,2) 
print('电脑出拳：%d'%computer) 
if inp >2: 
    print('输入错误') 
elif inp == 0 and computer == 2: 
    print('厉害了，居然赢了') 
elif inp == 1 and computer == 0: 
    print('厉害了，居然赢了') 
elif inp == 2 and computer == 1: 
    print('厉害了，居然赢了') 
elif inp == computer: 
    print('不错，居然平手') 
else: 
    print('哈哈，输了吧！')
# Out:
# 请出拳：0
# 电脑出拳：2
# 厉害了，居然赢了

# %% [markdown]
# ## 嵌套

# %%
num =int(input("输入一个数字："))
if num%2==0:    
    if num%3==0:        
        print('你输入的数字可以整除 2和3')    
    else:        
        print('你输入的数字可以整除2,但不能整除3')
else:    
    if num%3==0:        
        print('你输入的数字可以整除3，但是不能整除 2')    
    else:
        print('你输入的数字不能整除2和3')
# Out:
# 输入一个数字：8
# 你输入的数字可以整除2,但不能整除3

# %% [markdown]
# # 循环

# %% [markdown]
# 刚才的猜拳游戏每次运行只能猜一次，
# 那怎么运行一次可以一直玩呢？
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## while 循环

# %%
i = 0
while i < 5:#满足i小于5进入循环
    print('第%d次循环'%i)
    print('i=%d'%i)#循环时一直打印上述两句
    i += 1 #每次循环i值加1
# Out:
# 第0次循环
# i=0
# 第1次循环
# i=1
# 第2次循环
# i=2
# 第3次循环
# i=3
# 第4次循环
# i=4

# %%
import random  
# 导入生成随机数模块
while True:    
    inp = int(input('请出拳：'))    
    # 电脑随机出拳    
    computer = random.randint(0,2)    
    print('电脑出拳：%d'%computer)    
    if inp >2:        
        print('输入错误')    
    elif inp == 0 and computer == 2:        
        print('厉害了，居然赢了')    
    elif inp == 1 and computer == 0:        
        print('厉害了，居然赢了')    
    elif inp == 2 and computer == 1:        
        print('厉害了，居然赢了')    
    elif inp == computer:        
        print('不错，居然平手')    
    else:        
        print('哈哈，输了吧！')
# Out:
# 请出拳：2
# 电脑出拳：2
# 不错，居然平手
# 请出拳：3
# 电脑出拳：2
# 输入错误
# 请出拳：4
# 电脑出拳：0
# 输入错误
# 请出拳：5
# 电脑出拳：0
# 输入错误
# 请出拳：1
# 电脑出拳：2
# 哈哈，输了吧！
# 请出拳：0
# 电脑出拳：1
# 哈哈，输了吧！
# 请出拳：0
# 电脑出拳：2
# 厉害了，居然赢了
# 请出拳：1
# 电脑出拳：2
# 哈哈，输了吧！
# 请出拳：1
# 电脑出拳：2
# 哈哈，输了吧！
# 请出拳：2
# 电脑出拳：1
# 厉害了，居然赢了
# 请出拳：0
# 电脑出拳：0
# 不错，居然平手
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       2 # 导入生成随机数模块
#       3 while True:
# ----> 4     inp = int(input('请出拳：'))
#       5     # 电脑随机出拳
#       6     computer = random.randint(0,2)
#
# File D:\python\lib\site-packages\ipykernel\kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
#    1164     self.get_parent("shell"),
#    1165     password=False,
#    1166 )
#
# File D:\python\lib\site-packages\ipykernel\kernelbase.py:1205, in Kernel._input_request(self, prompt, ident, parent, password)
#    1202             break
#    1203 except KeyboardInterrupt:
#    1204     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1205     raise KeyboardInterrupt("Interrupted by user") from None
#    1206 except Exception:
#    1207     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## for循环

# %% [markdown]
# for跟while循环一样也可以完成循环。
# 在Python中for循环可以遍历任何序列的项目，如一个列表或者一个字符串等。

# %% [markdown]
# for 临时变量 in 字符串，列表等:
#     执行代码块
#     执行代码块

# %%
a = 'python'
for i in a:
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
li = ['a', 'b', 'c', 'd'] 
for i in li:
    print(i)
# Out:
# a
# b
# c
# d

# %% [markdown]
# ## break、continue语句

# %% [markdown]
# ### Python使用break来结束整个循环。程序遇到break将跳出循环，不再执行循环里面的代码。
# ### continue跳过本次循环，继续下一次循环

# %% [markdown]
# # 总结

# %% [markdown]
# ![image.png](attachment:image.png)
