# %% [markdown]
# # 计算机眼中的图像

# %%
import cv2
img = cv2.imread("1.jpg",0)
cv2.imshow("1",img)
cv2.waitKey(0)
# Out:
# -1

# %%
#展示图像数据
h,w = img.shape
with open("1.txt",'a') as f:
    for i in range(0,h):
        for j in range(0,w):
            if img[i][j]<=9:
                f.write(" "+str(img[i][j])+" ")
            elif(10<=img[i][j]<=99):
                f.write(str(img[i][j])+" ")
            else:
                f.write(str(img[i][j]))
        f.write("\n")

# %% [markdown]
# ## 一、矩阵（matrix）

# %% [markdown]
# ### 1、定义

# %% [markdown]
# **简单来说，矩阵就是充满数字的表格**。

# %% [markdown]
# 由 m × n 个数aij排成的m行n列的数表称为m行n列的矩阵，简称m × n矩阵。记作：
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/ca1f7faeef7f4432b2ec030799282db1.png)
#   这m×n 个数称为矩阵A的元素，简称为元，数aij位于矩阵A的第i行第j列，称为矩阵A的(i,j)元，以数 aij为(i,j)元的矩阵可记为(aij)或(aij)m × n，m×n矩阵A也记作Amn。

# %% [markdown]
# ### 2、基本运算

# %% [markdown]
# (1)矩阵加减法
#
#   两个矩阵相加或相减，需要满足两个矩阵的列数和行数一致。
#
#   加法交换律： A + B = B + A
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/97aaf13b76cb442aaab62656e2063bc9.png)
# (2)矩阵乘法
#   两个矩阵A和B相乘，需要满足A的列数等于B的行数
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/d4d0646ac279422bbb639378214ff4fc.png?x-oss-process=image/watermark,type_d3F5LXplbmhlaQ,shadow_50,text_Q1NETiBA5bCP5bWM5ZCM5a2m,size_20,color_FFFFFF,t_70,g_se,x_16)

# %%
练习

# %% [markdown]
# (3)数乘
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/b0f5e214da57483cb1a313b50454574d.png?x-oss-process=image/watermark,type_d3F5LXplbmhlaQ,shadow_50,text_Q1NETiBA5bCP5bWM5ZCM5a2m,size_10,color_FFFFFF,t_70,g_se,x_16)
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/db27b08e7dc741a9aca6337448c995de.png)
# 矩阵的加减法和矩阵的数乘合称矩阵的线性运算
#
# (4)转置
#   把矩阵A的行和列互相交换所产生的矩阵称为A的转置矩阵AT，这一过程称为矩阵的转置.
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/788b98f481f24618a7626e0e3d753a5b.png)
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/ef9b5594655940fb8b08f87c2fd4dd44.png)

# %% [markdown]
# ## 二、偏导数

# %% [markdown]
# ### 1、导数、偏导数

# %% [markdown]
# **导数（微分）**： 是代表函数（曲线）的斜率，是描述函数（曲线）变化快慢的量，同时曲线的极大值点也可以使用导数来判断，即极大值点的导数为0，此时斜率为零。

# %% [markdown]
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/52887ec31f7140a6a937e3a987da91a6.png)

# %% [markdown]
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/d011de139796457ca15fb2ef699959cf.png)

# %% [markdown]
# **偏导数**： 是指在多元函数的情况下，对其每个变量进行求导，求导时，把其他变量看做常量进行处理，物理意义就是查看这一个变量在其他情况不变的情况下对函数的影响程度。

# %%
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt


fig = plt.figure()
ax = Axes3D(fig)

x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
x,y = np.meshgrid(x,y)
r = 1/2*(np.square(x)-np.square(y))

ax.plot_surface(x,y,r,rstride = 1, cstride = 1,cmap=plt.get_cmap('gray'))
plt.show()
# Out:
# C:\Users\13016\AppData\Local\Temp\ipykernel_314420\3745383056.py:7: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 导数与偏导数本质是一致的，都是当自变量的变化量趋于0时，函数值的变化量与自变量变化量比值的极限；
# 偏导数也就是函数在某一点上沿某个坐标轴正方向的变化率；

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 导数指的是一元函数，函数y=f(x)在某一点处沿X轴正方向的变化率；
# 而偏导数，指的是多元函数中，函数y=f(x1,x2,...,xn)在某一点处沿某一坐标轴(x1,x2,...xn)正方向的变化率；

# %% [markdown]
# ### 2、梯度

# %% [markdown]
# **梯度**: 梯度的本意是一个向量（矢量），表示某一函数在该点处的方向导数沿着该方向取得最大值，即**函数在该点处沿着该方向（此梯度的方向）变化最快，变化率最大（为该梯度的模）**
#
#   简而言之，对多元函数的各个自变量求偏导数，并把求得的这些偏导数写成向量形式，就是梯度

# %% [markdown]
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/abe5daac2c00448a91618988e2d8a4f7.png)
# **梯度下降法**：是一种寻找函数极小值的方法。
#
#   该方法最普通的做法是：在已知参数当前值的情况下，按当前点对应的梯度向量的反方向(正方向是求最大值的)，并按事先给定好的步长大小，对参数进行调整。
#
#   按如上方法对参数做出多次调整之后，函数就会逼近一个极小值。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **那梯度下降法有什么用呢？**

# %% [markdown]
# 假设我们有一组图片需要分类。（图片1，小猫），（图片2，小狗）,(pic,lable)......进行训练神经网络，那么我们需要我们的神经网络可以拟合一个函数f(x)。这个函数很复杂，我们不可能求出来，只能近似求出这个函数。我们可以构造一个新的函数
# cost = (f(x)-lable)^2。需要让这个cost取得最小值，那么这个f(x)就是我们想要的。

# %% [markdown]
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/7d417437df8c4a7d967e8a093e561019.png?x-oss-process=image/watermark,type_d3F5LXplbmhlaQ,shadow_50,text_Q1NETiBA5bCP5bWM5ZCM5a2m,size_20,color_FFFFFF,t_70,g_se,x_16)
# **梯度下降法存在的问题：**
#   1.参数调整缓慢
#   2.收敛于局部最小值
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/bf37688ba55c41b3b4e99265f1e9b911.png?x-oss-process=image/watermark,type_d3F5LXplbmhlaQ,shadow_50,text_Q1NETiBA5bCP5bWM5ZCM5a2m,size_20,color_FFFFFF,t_70,g_se,x_16)
#   A为局部最小值，而B为全局最小值，若步长设置不恰当，则容易认为A是最小值，出现局部收敛

# %% [markdown]
# ## 三、概率学基础

# %% [markdown]
# ### 1、概率的基本概念
# (1) 概率：事件发生的可能性大小的度量，其严格定义如下：
#
#   概率P(g)为定义在事件集合上的满足下面2个条件的函数：
#   • 1)对任何事件A， P(A) >= 0
#   • 2)对必然事件B， P(B) = 1

# %% [markdown]
# ### 2、数学期望、方差、标准差

# %% [markdown]
# ###  3、正态分布（高斯分布）

# %% [markdown]
# 正态分布：若随机变量X服从一个数学期望为μ、方差为σ^2 (这个2表示平方)
# 的正态分布，记为N(μ， σ^2)。
#
# μ决定了其位置（中心线），其标准差σ决定了分布的幅度（胖瘦）。
#
# 标准正态分布：当μ = 0， σ = 1时的正态分布是标准正态分布

# %% [markdown]
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/d1c7dc88a07b4a849fea55821201bb84.png?x-oss-process=image/watermark,type_d3F5LXplbmhlaQ,shadow_50,text_Q1NETiBA5bCP5bWM5ZCM5a2m,size_20,color_FFFFFF,t_70,g_se,x_16)

# %% [markdown]
# ## 四、信息熵

# %% [markdown]
# 当系统的有序状态一致时，数据越集中的地方熵值越小，数据越分散的地方熵值越大。这是从信息的完整性上进行的描述。

# %% [markdown]
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/f0f07868738041929a177795d68b5653.png)

# %% [markdown]
# 假设我现在有两组数据。第一组数据：小猫20张，小狗20张。那么我们可以得到n=2  p1 = 1/2  p2 = 1/2。
# 我们计算可以得到Ent(A) = 1

# %% [markdown]
# 假如现在我的数据是小猫10张，小狗30张，那么我们可以得到n=2   p1=1/4  p2= 3/4
# 计算得到Ent(A) = 0.61

# %% [markdown]
# ## 五、卷积

# %% [markdown]
# 1 卷积计算
#
# 在图像处理中，图像是以二维矩阵的形式输入到神经网络中。给定一个图像和滤波器(卷积核)：具体计算过程如下图所示
# ![在这里插入图片描述](https://img-blog.csdnimg.cn/9d7ad197c1c7437caf51f9e3a2080258.png)
